# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('cricketData1.csv')

# %%
df.head()
# Out:
#              Player       Span  Mat  Inns  NO  Runs    HS    Ave      BF  \
# 0  DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94     NaN
# 1    HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15  1287.0
# 2    AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87  2667.0
# 3   RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707.0
# 4   GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416.0
#
#       SR  100  50  0   4s  6s
# 0    NaN   29  13  7  626   6
# 1  91.76    4   7  1  141  23
# 2  55.68    5   4  2  186   5
# 3  54.48    7  11  1  246  11
# 4  56.00   10   5  2  104   1

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave       BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94      NaN
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287.0
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667.0
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97   1707.0
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83    416.0
# ..                ...        ...  ...   ...  ..   ...   ...    ...      ...
# 57   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26   8662.0
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525.0
# 59  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525.0
# 60    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21   3217.0
# 61   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00   2110.0
#
#        SR  100  50   0    4s  6s
# ...

# %%
df=df.rename(columns={'NO':'Not_Out','HS':'High_Score','SR':'Strike_Rate','BF':'Balls_Faced'})

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of                Player       Span  Mat  Inns  Not_Out  Runs High_Score    Ave  \
# 0    DG Bradman (AUS)  1928-1948   52    80       10  6996        334  99.94
# 1      HC Brook (ENG)  2022-2023   12    20        1  1181        186  62.15
# 2      AC Voges (AUS)  2015-2016   20    31        7  1485       269*  61.87
# 3     RG Pollock (SA)  1963-1970   23    41        4  2256        274  60.97
# 4     GA Headley (WI)  1930-1954   22    40        4  2190       270*  60.83
# ..                ...        ...  ...   ...      ...   ...        ...    ...
# 57   KD Walters (AUS)  1965-1981   74   125       14  5357        250  48.26
# 58  GC Smith (ICC/SA)  2002-2014  117   205       13  9265        277  48.25
# 59  GC Smith (ICC/SA)  2002-2014  117   205       13  9265        277  48.25
# 60    SJ McCabe (AUS)  1930-1938   39    62        5  2748        232  48.21
# 61   DR Jardine (ENG)  1928-1934   22    33        6  1296        127  48.00
#
# ...

# %%
df.isnull().sum()
# Out:
# Player         0
# Span           0
# Mat            0
# Inns           0
# Not_Out        0
# Runs           0
# High_Score     0
# Ave            0
# Balls_Faced    4
# Strike_Rate    4
# 100            0
# 50             0
# 0              0
# 4s             0
# 6s             0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Player         False
# Span           False
# Mat            False
# Inns           False
# Not_Out        False
# Runs           False
# High_Score     False
# Ave            False
# Balls_Faced     True
# Strike_Rate     True
# 100            False
# 50             False
# 0              False
# 4s             False
# 6s             False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#                   Player       Span  Mat  Inns  Not_Out  Runs High_Score  \
# 0       DG Bradman (AUS)  1928-1948   52    80       10  6996        334
# 8         ED Weekes (WI)  1948-1958   48    81        5  4455        207
# 14       CL Walcott (WI)  1948-1960   44    74        7  3798        220
# 54  Hon.FS Jackson (ENG)  1893-1905   20    33        4  1415       144*
#
#       Ave  Balls_Faced  Strike_Rate  100  50  0   4s  6s
# 0   99.94          NaN          NaN   29  13  7  626   6
# 8   58.61          NaN          NaN   15  19  6  258   2
# 14  56.68          NaN          NaN   15  14  1  107  11
# 54  48.79          NaN          NaN    5   6  3   51   0

# %%
df['Balls_Faced']=df['Balls_Faced'].fillna(0)

# %%
df['Strike_Rate']=df['Strike_Rate'].fillna(0)

# %%
df[df['Player']=='DG Bradman (AUS)']
# Out:
#              Player       Span  Mat  Inns  Not_Out  Runs High_Score    Ave  \
# 0  DG Bradman (AUS)  1928-1948   52    80       10  6996        334  99.94
#
#    Balls_Faced  Strike_Rate  100  50  0   4s  6s
# 0          0.0          0.0   29  13  7  626   6

# %%
df[df['Player']=='ED Weekes (WI)']
# Out:
#            Player       Span  Mat  Inns  Not_Out  Runs High_Score    Ave  \
# 8  ED Weekes (WI)  1948-1958   48    81        5  4455        207  58.61
#
#    Balls_Faced  Strike_Rate  100  50  0   4s  6s
# 8          0.0          0.0   15  19  6  258   2

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 57    False
# 58    False
# 59     True
# 60    False
# 61    False
# Length: 62, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#                Player       Span  Mat  Inns  Not_Out   Runs High_Score    Ave  \
# 26   BC Lara (ICC/WI)  1990-2006  131   232        6  11953       400*  52.88
# 43  DCS Compton (ENG)  1937-1957   78   131       15   5807        278  50.06
# 59  GC Smith (ICC/SA)  2002-2014  117   205       13   9265        277  48.25
#
#     Balls_Faced  Strike_Rate  100  50   0    4s  6s
# 26      19753.0        60.51   34  48  17  1559  88
# 43       2731.0        38.81   17  28  10   342   3
# 59      15525.0        59.67   27  38  11  1165  24

# %%
df[df['Player'].isin(['BC Lara (ICC/WI)','DCS Compton (ENG)','GC Smith (ICC/SA)'])]
# Out:
#                Player       Span  Mat  Inns  Not_Out   Runs High_Score    Ave  \
# 25   BC Lara (ICC/WI)  1990-2006  131   232        6  11953       400*  52.88
# 26   BC Lara (ICC/WI)  1990-2006  131   232        6  11953       400*  52.88
# 42  DCS Compton (ENG)  1937-1957   78   131       15   5807        278  50.06
# 43  DCS Compton (ENG)  1937-1957   78   131       15   5807        278  50.06
# 58  GC Smith (ICC/SA)  2002-2014  117   205       13   9265        277  48.25
# 59  GC Smith (ICC/SA)  2002-2014  117   205       13   9265        277  48.25
#
#     Balls_Faced  Strike_Rate  100  50   0    4s  6s
# 25      19753.0        60.51   34  48  17  1559  88
# 26      19753.0        60.51   34  48  17  1559  88
# 42       2731.0        38.81   17  28  10   342   3
# 43       2731.0        38.81   17  28  10   342   3
# 58      15525.0        59.67   27  38  11  1165  24
# 59      15525.0        59.67   27  38  11  1165  24

# %%
df=df.drop_duplicates()

# %%
df[df['Player'].isin(['BC Lara (ICC/WI)','DCS Compton (ENG)','GC Smith (ICC/SA)'])]
# Out:
#                Player       Span  Mat  Inns  Not_Out   Runs High_Score    Ave  \
# 25   BC Lara (ICC/WI)  1990-2006  131   232        6  11953       400*  52.88
# 42  DCS Compton (ENG)  1937-1957   78   131       15   5807        278  50.06
# 58  GC Smith (ICC/SA)  2002-2014  117   205       13   9265        277  48.25
#
#     Balls_Faced  Strike_Rate  100  50   0    4s  6s
# 25      19753.0        60.51   34  48  17  1559  88
# 42       2731.0        38.81   17  28  10   342   3
# 58      15525.0        59.67   27  38  11  1165  24

# %%
df['Span'].dtypes
# Out:
# dtype('O')

# %%
df.info
# Out:
# <bound method DataFrame.info of                       Player       Span  Mat  Inns  Not_Out   Runs High_Score  \
# 0           DG Bradman (AUS)  1928-1948   52    80       10   6996        334
# 1             HC Brook (ENG)  2022-2023   12    20        1   1181        186
# 2             AC Voges (AUS)  2015-2016   20    31        7   1485       269*
# 3            RG Pollock (SA)  1963-1970   23    41        4   2256        274
# 4            GA Headley (WI)  1930-1954   22    40        4   2190       270*
# 5          H Sutcliffe (ENG)  1924-1935   54    84        9   4555        194
# 6            E Paynter (ENG)  1931-1939   20    31        5   1540        243
# 7        KF Barrington (ENG)  1955-1968   82   131       15   6806        256
# 8             ED Weekes (WI)  1948-1958   48    81        5   4455        207
# 9           WR Hammond (ENG)  1927-1947   85   140       16   7249       336*
# 10           SPD Smith (AUS)  2010-2024  106   189       24   9537        239
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59 entries, 0 to 61
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player       59 non-null     object
#  1   Span         59 non-null     object
#  2   Mat          59 non-null     int64
#  3   Inns         59 non-null     int64
#  4   Not_Out      59 non-null     int64
#  5   Runs         59 non-null     int64
#  6   High_Score   59 non-null     object
#  7   Ave          59 non-null     float64
#  8   Balls_Faced  59 non-null     float64
#  9   Strike_Rate  59 non-null     float64
#  10  100          59 non-null     int64
#  11  50           59 non-null     int64
#  12  0            59 non-null     int64
#  13  4s           59 non-null     int64
#  14  6s           59 non-null     int64
# dtypes: float64(3), int64(9), object(3)
# memory usage: 7.4+ KB

# %%
df['0'].dtypes
# Out:
# dtype('int64')

# %%
df['Player'].dtypes
# Out:
# dtype('O')

# %%
df['Span'].str.split(pat='-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
# 5     [1924, 1935]
# 6     [1931, 1939]
# 7     [1955, 1968]
# 8     [1948, 1958]
# 9     [1927, 1947]
# 10    [2010, 2024]
# 11    [1954, 1974]
# 12    [2000, 2015]
# 13    [1908, 1930]
# 14    [1948, 1960]
# 15    [1937, 1955]
# 16    [1995, 2013]
# 17    [1921, 1929]
# 18    [2010, 2023]
# 19    [1968, 1973]
# 20    [1993, 1995]
# 21    [1970, 1984]
# 22    [1935, 1951]
# 23    [1989, 2013]
# 24    [2019, 2023]
# 25    [1990, 2006]
# 27    [1996, 2012]
# 28    [1998, 2010]
# 29    [2000, 2017]
# 30    [2018, 2024]
# 31    [1995, 2012]
# 32    [1920, 1929]
# 33    [1992, 2002]
# 34    [2005, 2013]
# 35    [1994, 2015]
# 36    [1971, 1987]
# 37    [1985, 2004]
# 38    [1994, 2009]
# 39    [2004, 2018]
# 40    [1978, 1994]
# 41    [2012, 2023]
# 42    [1937, 1957]
# 44    [1997, 2014]
# 45    [1992, 2007]
# 46    [1948, 1963]
# 47    [1911, 1928]
# 48    [2001, 2013]
# ...

# %%
df['Span'].str.split(pat='-').str[0]
# Out:
# 0     1928
# 1     2022
# 2     2015
# 3     1963
# 4     1930
# 5     1924
# 6     1931
# 7     1955
# 8     1948
# 9     1927
# 10    2010
# 11    1954
# 12    2000
# 13    1908
# 14    1948
# 15    1937
# 16    1995
# 17    1921
# 18    2010
# 19    1968
# 20    1993
# 21    1970
# 22    1935
# 23    1989
# 24    2019
# 25    1990
# 27    1996
# 28    1998
# 29    2000
# 30    2018
# 31    1995
# 32    1920
# 33    1992
# 34    2005
# 35    1994
# 36    1971
# 37    1985
# 38    1994
# 39    2004
# 40    1978
# 41    2012
# 42    1937
# 44    1997
# 45    1992
# 46    1948
# 47    1911
# 48    2001
# 49    2019
# 50    2011
# 51    2004
# 52    1961
# 53    1929
# 54    1893
# 55    2001
# 56    1948
# 57    1965
# 58    2002
# 60    1930
# 61    1928
# Name: Span, dtype: object

# %%
df['Rookie_Year']=df['Span'].str.split(pat='-').str[0]
# Out:
# /var/folders/hk/n9zhgl_55rd_zmv9flwps28r0000gn/T/ipykernel_17556/1740907504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rookie_Year']=df['Span'].str.split(pat='-').str[0]

# %%
df['Retirement_Year']=df['Span'].str.split(pat='-').str[1]
# Out:
# /var/folders/hk/n9zhgl_55rd_zmv9flwps28r0000gn/T/ipykernel_17556/4214777975.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Retirement_Year']=df['Span'].str.split(pat='-').str[1]

# %%
df
# Out:
#                       Player       Span  Mat  Inns  Not_Out   Runs High_Score  \
# 0           DG Bradman (AUS)  1928-1948   52    80       10   6996        334
# 1             HC Brook (ENG)  2022-2023   12    20        1   1181        186
# 2             AC Voges (AUS)  2015-2016   20    31        7   1485       269*
# 3            RG Pollock (SA)  1963-1970   23    41        4   2256        274
# 4            GA Headley (WI)  1930-1954   22    40        4   2190       270*
# 5          H Sutcliffe (ENG)  1924-1935   54    84        9   4555        194
# 6            E Paynter (ENG)  1931-1939   20    31        5   1540        243
# 7        KF Barrington (ENG)  1955-1968   82   131       15   6806        256
# 8             ED Weekes (WI)  1948-1958   48    81        5   4455        207
# 9           WR Hammond (ENG)  1927-1947   85   140       16   7249       336*
# 10           SPD Smith (AUS)  2010-2024  106   189       24   9537        239
# ...

# %%
df=df.drop(['Span'], axis=1)

# %%
df.head()
# Out:
#              Player  Mat  Inns  Not_Out  Runs High_Score    Ave  Balls_Faced  \
# 0  DG Bradman (AUS)   52    80       10  6996        334  99.94          0.0
# 1    HC Brook (ENG)   12    20        1  1181        186  62.15       1287.0
# 2    AC Voges (AUS)   20    31        7  1485       269*  61.87       2667.0
# 3   RG Pollock (SA)   23    41        4  2256        274  60.97       1707.0
# 4   GA Headley (WI)   22    40        4  2190       270*  60.83        416.0
#
#    Strike_Rate  100  50  0   4s  6s Rookie_Year Retirement_Year
# 0         0.00   29  13  7  626   6        1928            1948
# 1        91.76    4   7  1  141  23        2022            2023
# 2        55.68    5   4  2  186   5        2015            2016
# 3        54.48    7  11  1  246  11        1963            1970
# 4        56.00   10   5  2  104   1        1930            1954

# %%
df['Player'].str.split(pat='(')
# Out:
# 0             [DG Bradman , AUS)]
# 1               [HC Brook , ENG)]
# 2               [AC Voges , AUS)]
# 3              [RG Pollock , SA)]
# 4              [GA Headley , WI)]
# 5            [H Sutcliffe , ENG)]
# 6              [E Paynter , ENG)]
# 7          [KF Barrington , ENG)]
# 8               [ED Weekes , WI)]
# 9             [WR Hammond , ENG)]
# 10             [SPD Smith , AUS)]
# 11              [GS Sobers , WI)]
# 12          [KC Sangakkara , SL)]
# 13              [JB Hobbs , ENG)]
# 14             [CL Walcott , WI)]
# 15              [L Hutton , ENG)]
# 16          [JH Kallis , ICC/SA)]
# 17          [GE Tyldesley , ENG)]
# 18          [KS Williamson , NZ)]
# 19               [CA Davis , WI)]
# 20             [VG Kambli , IND)]
# 21           [GS Chappell , AUS)]
# 22              [AD Nourse , SA)]
# 23          [SR Tendulkar , IND)]
# 24            [DJ Mitchell , NZ)]
# 25            [BC Lara , ICC/WI)]
# 27          [R Dravid , ICC/IND)]
# ...

# %%
df['Country']=df['Player'].str.split(pat='(').str[1]

# %%
df['Country']
# Out:
# 0         AUS)
# 1         ENG)
# 2         AUS)
# 3          SA)
# 4          WI)
# 5         ENG)
# 6         ENG)
# 7         ENG)
# 8          WI)
# 9         ENG)
# 10        AUS)
# 11         WI)
# 12         SL)
# 13        ENG)
# 14         WI)
# 15        ENG)
# 16     ICC/SA)
# 17        ENG)
# 18         NZ)
# 19         WI)
# 20        IND)
# 21        AUS)
# 22         SA)
# 23        IND)
# 24         NZ)
# 25     ICC/WI)
# 27    ICC/IND)
# 28        PAK)
# 29        PAK)
# 30        AUS)
# 31        AUS)
# 32        AUS)
# 33        ZIM)
# 34        AUS)
# 35         WI)
# 36        IND)
# 37        AUS)
# 38        AUS)
# 39         SA)
# 40        AUS)
# 41        ENG)
# 42        ENG)
# 44         SL)
# 45    ICC/PAK)
# 46         WI)
# 47        ENG)
# 48    ICC/IND)
# 49        PAK)
# 50        IND)
# 51        AUS)
# 52         SA)
# 53         SA)
# 54        ENG)
# 55         SL)
# 56        AUS)
# 57        AUS)
# 58     ICC/SA)
# 60        AUS)
# ...

# %%
df['Country']=df['Country'].str.split(pat=')').str[0]

# %%
df['Player']=df['Player'].str.split(pat='(').str[0]

# %%
df.head()
# Out:
#         Player  Mat  Inns  Not_Out  Runs High_Score    Ave  Balls_Faced  \
# 0  DG Bradman    52    80       10  6996        334  99.94          0.0
# 1    HC Brook    12    20        1  1181        186  62.15       1287.0
# 2    AC Voges    20    31        7  1485       269*  61.87       2667.0
# 3  RG Pollock    23    41        4  2256        274  60.97       1707.0
# 4  GA Headley    22    40        4  2190       270*  60.83        416.0
#
#    Strike_Rate  100  50  0   4s  6s Rookie_Year Retirement_Year Country
# 0         0.00   29  13  7  626   6        1928            1948     AUS
# 1        91.76    4   7  1  141  23        2022            2023     ENG
# 2        55.68    5   4  2  186   5        2015            2016     AUS
# 3        54.48    7  11  1  246  11        1963            1970      SA
# 4        56.00   10   5  2  104   1        1930            1954      WI

# %%
df.dtypes
# Out:
# Player              object
# Mat                  int64
# Inns                 int64
# Not_Out              int64
# Runs                 int64
# High_Score          object
# Ave                float64
# Balls_Faced        float64
# Strike_Rate        float64
# 100                  int64
# 50                   int64
# 0                    int64
# 4s                   int64
# 6s                   int64
# Rookie_Year         object
# Retirement_Year     object
# Country             object
# dtype: object

# %%
df['High_Score'].str.split(pat='*').str[0]
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
# 5     194
# 6     243
# 7     256
# 8     207
# 9     336
# 10    239
# 11    365
# 12    319
# 13    211
# 14    220
# 15    364
# 16    224
# 17    122
# 18    251
# 19    183
# 20    227
# 21    247
# 22    231
# 23    248
# 24    190
# 25    400
# 27    270
# 28    223
# 29    313
# 30    215
# 31    257
# 32    201
# 33    232
# 34    195
# 35    203
# 36    236
# 37    200
# 38    380
# 39    278
# 40    205
# 41    254
# 42    278
# 44    374
# 45    329
# 46    261
# 47    182
# 48    319
# 49    215
# 50    254
# 51    329
# 52    144
# 53    189
# 54    144
# 55    231
# 56    205
# 57    250
# 58    277
# 60    232
# 61    127
# Name: High_Score, dtype: object

# %%
df['High_Score']=df['High_Score'].str.split(pat='*').str[0]

# %%
df['High_Score'].astype('int')
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
# 5     194
# 6     243
# 7     256
# 8     207
# 9     336
# 10    239
# 11    365
# 12    319
# 13    211
# 14    220
# 15    364
# 16    224
# 17    122
# 18    251
# 19    183
# 20    227
# 21    247
# 22    231
# 23    248
# 24    190
# 25    400
# 27    270
# 28    223
# 29    313
# 30    215
# 31    257
# 32    201
# 33    232
# 34    195
# 35    203
# 36    236
# 37    200
# 38    380
# 39    278
# 40    205
# 41    254
# 42    278
# 44    374
# 45    329
# 46    261
# 47    182
# 48    319
# 49    215
# 50    254
# 51    329
# 52    144
# 53    189
# 54    144
# 55    231
# 56    205
# 57    250
# 58    277
# 60    232
# 61    127
# Name: High_Score, dtype: int64

# %%
df['High_Score']=df['High_Score'].astype('int')

# %%
df=df.astype({'Rookie_Year':'int','Retirement_Year':'int'})

# %%
df.dtypes
# Out:
# Player              object
# Mat                  int64
# Inns                 int64
# Not_Out              int64
# Runs                 int64
# High_Score           int64
# Ave                float64
# Balls_Faced        float64
# Strike_Rate        float64
# 100                  int64
# 50                   int64
# 0                    int64
# 4s                   int64
# 6s                   int64
# Rookie_Year          int64
# Retirement_Year      int64
# Country             object
# dtype: object

# %%
df.head()
# Out:
#         Player  Mat  Inns  Not_Out  Runs  High_Score    Ave  Balls_Faced  \
# 0  DG Bradman    52    80       10  6996         334  99.94          0.0
# 1    HC Brook    12    20        1  1181         186  62.15       1287.0
# 2    AC Voges    20    31        7  1485         269  61.87       2667.0
# 3  RG Pollock    23    41        4  2256         274  60.97       1707.0
# 4  GA Headley    22    40        4  2190         270  60.83        416.0
#
#    Strike_Rate  100  50  0   4s  6s  Rookie_Year  Retirement_Year Country
# 0         0.00   29  13  7  626   6         1928             1948     AUS
# 1        91.76    4   7  1  141  23         2022             2023     ENG
# 2        55.68    5   4  2  186   5         2015             2016     AUS
# 3        54.48    7  11  1  246  11         1963             1970      SA
# 4        56.00   10   5  2  104   1         1930             1954      WI

# %%
df.isnull().any()
# Out:
# Player             False
# Mat                False
# Inns               False
# Not_Out            False
# Runs               False
# High_Score         False
# Ave                False
# Balls_Faced        False
# Strike_Rate        False
# 100                False
# 50                 False
# 0                  False
# 4s                 False
# 6s                 False
# Rookie_Year        False
# Retirement_Year    False
# Country            False
# dtype: bool

# %%
df.dtypes
# Out:
# Player              object
# Mat                  int64
# Inns                 int64
# Not_Out              int64
# Runs                 int64
# High_Score           int64
# Ave                float64
# Balls_Faced        float64
# Strike_Rate        float64
# 100                  int64
# 50                   int64
# 0                    int64
# 4s                   int64
# 6s                   int64
# Rookie_Year          int64
# Retirement_Year      int64
# Country             object
# dtype: object

# %%
df['Career_Length']=df['Retirement_Year']-df['Rookie_Year']

# %%
df
# Out:
#                Player  Mat  Inns  Not_Out   Runs  High_Score    Ave  \
# 0         DG Bradman    52    80       10   6996         334  99.94
# 1           HC Brook    12    20        1   1181         186  62.15
# 2           AC Voges    20    31        7   1485         269  61.87
# 3         RG Pollock    23    41        4   2256         274  60.97
# 4         GA Headley    22    40        4   2190         270  60.83
# 5        H Sutcliffe    54    84        9   4555         194  60.73
# 6          E Paynter    20    31        5   1540         243  59.23
# 7      KF Barrington    82   131       15   6806         256  58.67
# 8          ED Weekes    48    81        5   4455         207  58.61
# 9         WR Hammond    85   140       16   7249         336  58.45
# 10         SPD Smith   106   189       24   9537         239  57.80
# 11         GS Sobers    93   160       21   8032         365  57.78
# 12     KC Sangakkara   134   233       17  12400         319  57.40
# ...

# %%
df['Career_Length'].mean()
# Out:
# 13.067796610169491

# %%
df[df['Career_Length']>10]['Strike_Rate'].mean()
# Out:
# 46.08547619047619

# %%
df[df['Rookie_Year']<1960]
# Out:
#              Player  Mat  Inns  Not_Out  Runs  High_Score    Ave  Balls_Faced  \
# 0       DG Bradman    52    80       10  6996         334  99.94          0.0
# 4       GA Headley    22    40        4  2190         270  60.83        416.0
# 5      H Sutcliffe    54    84        9  4555         194  60.73       6558.0
# 6        E Paynter    20    31        5  1540         243  59.23       1288.0
# 7    KF Barrington    82   131       15  6806         256  58.67       4957.0
# 8        ED Weekes    48    81        5  4455         207  58.61          0.0
# 9       WR Hammond    85   140       16  7249         336  58.45       7491.0
# 11       GS Sobers    93   160       21  8032         365  57.78       4063.0
# 13        JB Hobbs    61   102        7  5410         211  56.94       5363.0
# 14      CL Walcott    44    74        7  3798         220  56.68          0.0
# 15        L Hutton    79   138       15  6971         364  56.67       2844.0
# ...

# %%
df[df['Rookie_Year']<1960]['Player'].count()
# Out:
# 22

# %%
df.groupby('Country')['High_Score'].max()
# Out:
# Country
# AUS        380
# ENG        364
# ICC/IND    319
# ICC/PAK    329
# ICC/SA     277
# ICC/WI     400
# IND        254
# NZ         251
# PAK        313
# SA         278
# SL         374
# WI         365
# ZIM        232
# Name: High_Score, dtype: int64

# %%
df.groupby('Country')['High_Score'].max().to_frame('Highincountry').reset_index().sort_values('Highincountry',ascending=False)
# Out:
#     Country  Highincountry
# 5    ICC/WI            400
# 0       AUS            380
# 10       SL            374
# 11       WI            365
# 1       ENG            364
# 3   ICC/PAK            329
# 2   ICC/IND            319
# 8       PAK            313
# 9        SA            278
# 4    ICC/SA            277
# 6       IND            254
# 7        NZ            251
# 12      ZIM            232

# %%
df.groupby('Country')[['100','50','0']].mean()
# Out:
#                100         50          0
# Country
# AUS      21.533333  29.733333   9.000000
# ENG      12.307692  20.769231   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       17.000000  21.000000   5.500000
# PAK      20.666667  23.000000  10.666667
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       15.571429  22.857143   6.857143
# ZIM      12.000000  27.000000   5.000000
